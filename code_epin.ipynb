# %%
import networkx as nx

import matplotlib.pyplot as plt
import random
import json
import community as community_louvain

import numpy as np

import numpy as np
from scipy.sparse import csr_matrix

# 设置随机种子
random.seed(42)
np.random.seed(42)
from networkx.algorithms.community import girvan_newman

# %%
path = '/Users/qing/Desktop/24s1/comp8880/project/code/data/soc/soc-Epinions1.txt'
G = read_directed_graph(path,3)

# %%
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()

num_nodes, num_edges
# Out:
# (75879, 508837)

# %%
with open('saved/network_metrics_slash.json', 'r') as f:
    loaded_data = json.load(f)

# 访问加载的数据
sorted_centrality = loaded_data["Centrality"]
sorted_pagerank =  loaded_data["PageRank"]
sorted_leaderRank =  loaded_data["LeaderRank"]
sorted_hIndex =  loaded_data["HIndex"]
sorted_kShell=  loaded_data["KShell"]
# 更多的访问可以根据需要添加

# %%
print(sorted_centrality[:3])
print(sorted_pagerank[:3])
print(sorted_leaderRank[:3])
print(sorted_hIndex[:3])
print(sorted_kShell[:3])
# Out:
# [['2481', 0.06522835093524994], ['394', 0.05848059049367236], ['4675', 0.05749815793895991]]
# [['2481', 0.0029730052356006587], ['394', 0.0026745576707996746], ['34', 0.002341799463228293]]
# [['2481', 0.0021783055563750196], ['34', 0.0020590574294100297], ['377', 0.0019739963840719587]]
# [['4675', 267], ['46', 254], ['192', 241]]
# [['8', 106], ['46', 106], ['83', 106]]

# %%
def plot_sir_simulation(G, sorted_maps, top, infection_prob=0.05, steps=100):
    plt.figure(figsize=(10, 5))

    # Calculate average in-degree
    avg_in_degree = sum(dict(G.in_degree()).values()) / G.number_of_nodes()
    print(avg_in_degree)
    recovery_prob = 1 / avg_in_degree

    # Iterate through all sorted maps
    for name, sorted_map in sorted_maps.items():
        top_nodes = [node for node, _ in sorted_map[:top]]  # Extract top nodes
        history, ever_infected, infected_counts = SIR_simulation(G, top_nodes, infection_prob, 1, steps)
        plt.plot(infected_counts, marker='o', linestyle='-', label=f'{name}: Top {top}')

    plt.title('Number of Ever Infected Nodes Over Time')
    plt.xlabel('Time Steps')
    plt.ylabel('Number of Ever Infected Nodes')
    plt.grid(True)
    plt.legend()
    plt.show()

def SIR_simulation(G, initial_infected, infection_prob=0.1, recovery_prob=0.05, steps=100):
    # Initialize the status of each node
    status = {node: 'S' for node in G.nodes()}
    for node in initial_infected:
        status[node] = 'I'

    history = []
    ever_infected = set(initial_infected)
    infected_counts = [len(ever_infected)]  # Initial number of infected nodes

    # Simulation process
    for _ in range(steps):
        new_status = status.copy()
        for node in G.nodes():
            if status[node] == 'I':
                for neighbor in G.neighbors(node):
                    if status[neighbor] == 'S' and random.random() < infection_prob:
                        new_status[neighbor] = 'I'
                        ever_infected.add(neighbor)
                if random.random() < recovery_prob:
                    new_status[node] = 'R'
        history.append(new_status)
        status = new_status
        infected_counts.append(len(ever_infected))  # Record the total number of infected nodes

        if not any(s == 'I' for s in status.values()):
            break

    return history, ever_infected, infected_counts


sorted_maps = {
    "Centrality": sorted_centrality,
    "PageRank": sorted_pagerank,
    "LeaderRank": sorted_leaderRank,
    "H-index": sorted_hIndex,
    "K-Shell": sorted_kShell
}


# 运行模拟并绘图
plot_sir_simulation(G, sorted_maps,top=10, infection_prob=0.015,steps=10)
# Out:
# 6.7059001831863885

# %%
# 使用Louvain算法进行社区检测
def detect_communities(G):
    partition = community_louvain.best_partition(G)
    return partition


# 统计前top节点在各社区中的分布
def count_top_nodes_in_communities(G, sorted_maps, top, partition):
    community_counts = {name: {} for name in sorted_maps.keys()}
    
    for name, sorted_map in sorted_maps.items():
        top_nodes = [node for node, _ in sorted_map[:top]]  # 提取前top个节点
        for node in top_nodes:
            community = partition[node]
            if community not in community_counts[name]:
                community_counts[name][community] = 0
            community_counts[name][community] += 1
    
    return community_counts

# 可视化前top节点在各社区中的分布
def plot_top_nodes_distribution(community_counts, top):
    plt.figure(figsize=(15, 10))

    for i, (name, counts) in enumerate(community_counts.items()):
        communities = list(counts.keys())
        counts = list(counts.values())
        
        plt.subplot(3, 3, i + 1)
        plt.bar(communities, counts)
        plt.title(f'Distribution of Top {top} Nodes in Communities\n({name})')
        plt.xlabel('Community')
        plt.ylabel('Number of Top Nodes')

    plt.tight_layout()
    plt.show()

# 统计每个社区的节点数量并排序
def count_and_sort_communities(partition):
    community_counts = {}
    for node, community in partition.items():
        if community not in community_counts:
            community_counts[community] = 0
        community_counts[community] += 1
    
    # 按照节点数量排序社区
    sorted_community_counts = sorted(community_counts.items(), key=lambda x: x[1], reverse=True)
    return sorted_community_counts

# %%
# 示例：检测社区并统计前top节点的分布
G_edge = nx.read_edgelist('/Users/qing/Desktop/24s1/comp8880/project/code/data/soc/soc-Epinions1.txt')  # 加载您的网络数据
partition = detect_communities(G_edge)

# %%
top = 20
community_counts = count_top_nodes_in_communities(G_edge, sorted_maps, top, partition)
plot_top_nodes_distribution(community_counts, top)

# %%
sorted_community_counts = count_and_sort_communities(partition)

for community, count in sorted_community_counts:
    print(f"Community {community}: {count} nodes")
# Out:
# Community 2: 16948 nodes
# Community 0: 11957 nodes
# Community 1: 11347 nodes
# Community 4: 7803 nodes
# Community 3: 6804 nodes
# Community 11: 1894 nodes
# Community 8: 1192 nodes
# Community 10: 1116 nodes
# Community 104: 918 nodes
# Community 13: 887 nodes
# Community 56: 850 nodes
# Community 163: 833 nodes
# Community 48: 805 nodes
# Community 22: 629 nodes
# Community 34: 588 nodes
# Community 12: 496 nodes
# Community 29: 473 nodes
# Community 6: 428 nodes
# Community 64: 420 nodes
# Community 20: 404 nodes
# Community 77: 394 nodes
# Community 83: 389 nodes
# Community 62: 350 nodes
# Community 19: 328 nodes
# Community 7: 311 nodes
# Community 136: 280 nodes
# Community 110: 268 nodes
# Community 41: 256 nodes
# Community 32: 255 nodes
# Community 69: 228 nodes
# Community 65: 217 nodes
# Community 73: 209 nodes
# Community 63: 188 nodes
# Community 14: 161 nodes
# Community 101: 137 nodes
# Community 50: 110 nodes
# Community 25: 65 nodes
# Community 102: 63 nodes
# Community 93: 46 nodes
# Community 735: 45 nodes
# Community 162: 40 nodes
# Community 31: 38 nodes
# Community 9: 37 nodes
# Community 138: 35 nodes
# Community 723: 33 nodes
# Community 17: 32 nodes
# Community 248: 32 nodes
# Community 196: 30 nodes
# Community 53: 29 nodes
# Community 362: 29 nodes
# Community 61: 25 nodes
# Community 185: 24 nodes
# Community 212: 24 nodes
# Community 148: 23 nodes
# Community 88: 22 nodes
# Community 292: 22 nodes
# Community 321: 22 nodes
# Community 74: 21 nodes
# Community 92: 20 nodes
# Community 224: 20 nodes
# Community 263: 20 nodes
# Community 119: 18 nodes
# Community 339: 18 nodes
# Community 365: 18 nodes
# Community 446: 18 nodes
# Community 524: 18 nodes
# Community 66: 17 nodes
# Community 80: 17 nodes
# Community 181: 17 nodes
# Community 184: 17 nodes
# Community 236: 17 nodes
# Community 239: 17 nodes
# Community 336: 17 nodes
# Community 60: 16 nodes
# Community 254: 16 nodes
# Community 383: 16 nodes
# Community 518: 16 nodes
# Community 769: 16 nodes
# Community 151: 15 nodes
# Community 161: 15 nodes
# Community 176: 15 nodes
# Community 291: 15 nodes
# Community 305: 15 nodes
# Community 15: 14 nodes
# Community 37: 14 nodes
# Community 129: 14 nodes
# Community 170: 14 nodes
# Community 255: 14 nodes
# Community 384: 14 nodes
# Community 465: 14 nodes
# Community 517: 14 nodes
# Community 40: 13 nodes
# Community 71: 13 nodes
# Community 111: 13 nodes
# Community 123: 13 nodes
# Community 180: 13 nodes
# Community 202: 13 nodes
# Community 211: 13 nodes
# Community 215: 13 nodes
# Community 288: 13 nodes
# Community 416: 13 nodes
# Community 55: 12 nodes
# Community 95: 12 nodes
# Community 106: 12 nodes
# Community 108: 12 nodes
# Community 157: 12 nodes
# Community 171: 12 nodes
# Community 173: 12 nodes
# Community 207: 12 nodes
# Community 223: 12 nodes
# Community 262: 12 nodes
# Community 308: 12 nodes
# Community 361: 12 nodes
# Community 412: 12 nodes
# Community 539: 12 nodes
# Community 558: 12 nodes
# Community 24: 11 nodes
# Community 109: 11 nodes
# Community 118: 11 nodes
# Community 142: 11 nodes
# Community 150: 11 nodes
# Community 225: 11 nodes
# Community 375: 11 nodes
# Community 389: 11 nodes
# Community 393: 11 nodes
# Community 444: 11 nodes
# Community 634: 11 nodes
# Community 637: 11 nodes
# Community 121: 10 nodes
# Community 125: 10 nodes
# Community 133: 10 nodes
# Community 205: 10 nodes
# Community 230: 10 nodes
# Community 253: 10 nodes
# Community 270: 10 nodes
# Community 289: 10 nodes
# Community 303: 10 nodes
# Community 344: 10 nodes
# Community 358: 10 nodes
# Community 392: 10 nodes
# Community 401: 10 nodes
# Community 417: 10 nodes
# Community 435: 10 nodes
# Community 500: 10 nodes
# Community 503: 10 nodes
# Community 516: 10 nodes
# Community 536: 10 nodes
# Community 584: 10 nodes
# Community 616: 10 nodes
# Community 679: 10 nodes
# Community 51: 9 nodes
# Community 81: 9 nodes
# Community 98: 9 nodes
# Community 112: 9 nodes
# Community 131: 9 nodes
# Community 143: 9 nodes
# Community 158: 9 nodes
# Community 160: 9 nodes
# Community 190: 9 nodes
# Community 191: 9 nodes
# Community 219: 9 nodes
# Community 226: 9 nodes
# Community 244: 9 nodes
# Community 272: 9 nodes
# Community 372: 9 nodes
# Community 379: 9 nodes
# Community 394: 9 nodes
# Community 399: 9 nodes
# Community 408: 9 nodes
# Community 425: 9 nodes
# Community 431: 9 nodes
# Community 456: 9 nodes
# Community 511: 9 nodes
# Community 620: 9 nodes
# Community 654: 9 nodes
# Community 668: 9 nodes
# Community 690: 9 nodes
# Community 698: 9 nodes
# Community 762: 9 nodes
# Community 229: 9 nodes
# Community 86: 8 nodes
# Community 90: 8 nodes
# Community 97: 8 nodes
# Community 117: 8 nodes
# Community 145: 8 nodes
# Community 182: 8 nodes
# Community 252: 8 nodes
# Community 257: 8 nodes
# Community 271: 8 nodes
# Community 274: 8 nodes
# Community 284: 8 nodes
# Community 294: 8 nodes
# Community 312: 8 nodes
# Community 317: 8 nodes
# Community 324: 8 nodes
# Community 326: 8 nodes
# Community 337: 8 nodes
# Community 404: 8 nodes
# Community 406: 8 nodes
# Community 409: 8 nodes
# Community 413: 8 nodes
# Community 419: 8 nodes
# Community 428: 8 nodes
# Community 452: 8 nodes
# Community 457: 8 nodes
# Community 481: 8 nodes
# Community 482: 8 nodes
# Community 493: 8 nodes
# Community 510: 8 nodes
# Community 520: 8 nodes
# Community 521: 8 nodes
# Community 522: 8 nodes
# Community 525: 8 nodes
# Community 527: 8 nodes
# Community 533: 8 nodes
# Community 537: 8 nodes
# Community 555: 8 nodes
# Community 661: 8 nodes
# Community 665: 8 nodes
# Community 716: 8 nodes
# Community 740: 8 nodes
# Community 5: 8 nodes
# Community 172: 7 nodes
# Community 183: 7 nodes
# Community 187: 7 nodes
# Community 194: 7 nodes
# Community 214: 7 nodes
# Community 221: 7 nodes
# Community 240: 7 nodes
# Community 249: 7 nodes
# Community 260: 7 nodes
# Community 261: 7 nodes
# Community 265: 7 nodes
# Community 266: 7 nodes
# Community 273: 7 nodes
# Community 298: 7 nodes
# Community 301: 7 nodes
# Community 306: 7 nodes
# Community 310: 7 nodes
# Community 313: 7 nodes
# Community 322: 7 nodes
# Community 323: 7 nodes
# Community 351: 7 nodes
# Community 356: 7 nodes
# Community 357: 7 nodes
# Community 366: 7 nodes
# Community 385: 7 nodes
# Community 387: 7 nodes
# Community 396: 7 nodes
# Community 411: 7 nodes
# Community 424: 7 nodes
# Community 454: 7 nodes
# Community 470: 7 nodes
# Community 480: 7 nodes
# Community 486: 7 nodes
# Community 490: 7 nodes
# Community 498: 7 nodes
# Community 501: 7 nodes
# Community 507: 7 nodes
# Community 508: 7 nodes
# Community 528: 7 nodes
# Community 531: 7 nodes
# Community 532: 7 nodes
# Community 540: 7 nodes
# Community 552: 7 nodes
# Community 559: 7 nodes
# Community 564: 7 nodes
# Community 566: 7 nodes
# Community 615: 7 nodes
# Community 618: 7 nodes
# Community 651: 7 nodes
# Community 670: 7 nodes
# Community 685: 7 nodes
# Community 745: 7 nodes
# Community 761: 7 nodes
# Community 23: 6 nodes
# Community 103: 6 nodes
# Community 107: 6 nodes
# Community 113: 6 nodes
# Community 116: 6 nodes
# Community 122: 6 nodes
# Community 124: 6 nodes
# Community 144: 6 nodes
# Community 149: 6 nodes
# Community 174: 6 nodes
# Community 177: 6 nodes
# Community 197: 6 nodes
# Community 201: 6 nodes
# Community 203: 6 nodes
# Community 209: 6 nodes
# Community 222: 6 nodes
# Community 227: 6 nodes
# Community 233: 6 nodes
# Community 234: 6 nodes
# Community 237: 6 nodes
# Community 238: 6 nodes
# Community 256: 6 nodes
# Community 259: 6 nodes
# Community 278: 6 nodes
# Community 287: 6 nodes
# Community 332: 6 nodes
# Community 335: 6 nodes
# Community 343: 6 nodes
# Community 347: 6 nodes
# Community 367: 6 nodes
# Community 370: 6 nodes
# Community 374: 6 nodes
# Community 380: 6 nodes
# Community 382: 6 nodes
# Community 386: 6 nodes
# Community 398: 6 nodes
# Community 418: 6 nodes
# Community 433: 6 nodes
# Community 436: 6 nodes
# Community 437: 6 nodes
# Community 440: 6 nodes
# Community 451: 6 nodes
# Community 463: 6 nodes
# Community 488: 6 nodes
# Community 496: 6 nodes
# Community 499: 6 nodes
# Community 519: 6 nodes
# Community 530: 6 nodes
# Community 535: 6 nodes
# Community 554: 6 nodes
# Community 560: 6 nodes
# Community 572: 6 nodes
# Community 592: 6 nodes
# Community 595: 6 nodes
# Community 621: 6 nodes
# Community 629: 6 nodes
# Community 633: 6 nodes
# Community 635: 6 nodes
# Community 648: 6 nodes
# Community 657: 6 nodes
# Community 675: 6 nodes
# Community 676: 6 nodes
# Community 691: 6 nodes
# Community 714: 6 nodes
# Community 721: 6 nodes
# Community 750: 6 nodes
# Community 760: 6 nodes
# Community 782: 6 nodes
# Community 784: 6 nodes
# Community 46: 5 nodes
# Community 114: 5 nodes
# Community 115: 5 nodes
# Community 126: 5 nodes
# Community 128: 5 nodes
# Community 132: 5 nodes
# Community 134: 5 nodes
# Community 137: 5 nodes
# Community 159: 5 nodes
# Community 165: 5 nodes
# Community 167: 5 nodes
# Community 195: 5 nodes
# Community 198: 5 nodes
# Community 210: 5 nodes
# Community 217: 5 nodes
# Community 218: 5 nodes
# Community 228: 5 nodes
# Community 232: 5 nodes
# Community 241: 5 nodes
# Community 243: 5 nodes
# Community 245: 5 nodes
# Community 264: 5 nodes
# Community 268: 5 nodes
# Community 286: 5 nodes
# Community 290: 5 nodes
# Community 302: 5 nodes
# Community 307: 5 nodes
# Community 311: 5 nodes
# Community 314: 5 nodes
# Community 320: 5 nodes
# Community 325: 5 nodes
# Community 327: 5 nodes
# Community 330: 5 nodes
# Community 334: 5 nodes
# Community 348: 5 nodes
# Community 354: 5 nodes
# Community 359: 5 nodes
# Community 363: 5 nodes
# Community 373: 5 nodes
# Community 395: 5 nodes
# Community 403: 5 nodes
# Community 407: 5 nodes
# Community 410: 5 nodes
# Community 414: 5 nodes
# Community 415: 5 nodes
# Community 420: 5 nodes
# Community 422: 5 nodes
# Community 426: 5 nodes
# Community 429: 5 nodes
# Community 430: 5 nodes
# Community 439: 5 nodes
# Community 447: 5 nodes
# Community 455: 5 nodes
# Community 460: 5 nodes
# Community 464: 5 nodes
# Community 473: 5 nodes
# Community 475: 5 nodes
# Community 476: 5 nodes
# Community 479: 5 nodes
# Community 491: 5 nodes
# Community 494: 5 nodes
# Community 502: 5 nodes
# Community 514: 5 nodes
# Community 534: 5 nodes
# Community 542: 5 nodes
# Community 553: 5 nodes
# Community 556: 5 nodes
# Community 570: 5 nodes
# Community 574: 5 nodes
# Community 576: 5 nodes
# Community 577: 5 nodes
# Community 578: 5 nodes
# Community 581: 5 nodes
# Community 585: 5 nodes
# Community 589: 5 nodes
# Community 600: 5 nodes
# Community 611: 5 nodes
# Community 622: 5 nodes
# Community 626: 5 nodes
# Community 631: 5 nodes
# Community 642: 5 nodes
# Community 650: 5 nodes
# Community 664: 5 nodes
# Community 667: 5 nodes
# Community 680: 5 nodes
# Community 683: 5 nodes
# Community 686: 5 nodes
# Community 693: 5 nodes
# Community 695: 5 nodes
# Community 699: 5 nodes
# Community 713: 5 nodes
# Community 715: 5 nodes
# Community 736: 5 nodes
# Community 739: 5 nodes
# Community 743: 5 nodes
# Community 752: 5 nodes
# Community 755: 5 nodes
# Community 764: 5 nodes
# Community 780: 5 nodes
# Community 30: 5 nodes
# Community 38: 5 nodes
# Community 28: 4 nodes
# Community 35: 4 nodes
# Community 57: 4 nodes
# Community 59: 4 nodes
# Community 70: 4 nodes
# Community 72: 4 nodes
# Community 76: 4 nodes
# Community 82: 4 nodes
# Community 89: 4 nodes
# Community 91: 4 nodes
# Community 96: 4 nodes
# Community 120: 4 nodes
# Community 127: 4 nodes
# Community 130: 4 nodes
# Community 135: 4 nodes
# Community 146: 4 nodes
# Community 153: 4 nodes
# Community 154: 4 nodes
# Community 164: 4 nodes
# Community 166: 4 nodes
# Community 168: 4 nodes
# Community 175: 4 nodes
# Community 179: 4 nodes
# Community 193: 4 nodes
# Community 200: 4 nodes
# Community 213: 4 nodes
# Community 220: 4 nodes
# Community 235: 4 nodes
# Community 246: 4 nodes
# Community 250: 4 nodes
# Community 258: 4 nodes
# Community 277: 4 nodes
# Community 279: 4 nodes
# Community 281: 4 nodes
# Community 293: 4 nodes
# Community 295: 4 nodes
# Community 296: 4 nodes
# Community 297: 4 nodes
# Community 299: 4 nodes
# Community 300: 4 nodes
# Community 304: 4 nodes
# Community 309: 4 nodes
# Community 319: 4 nodes
# Community 328: 4 nodes
# Community 333: 4 nodes
# Community 338: 4 nodes
# Community 341: 4 nodes
# Community 353: 4 nodes
# Community 355: 4 nodes
# Community 368: 4 nodes
# Community 371: 4 nodes
# Community 381: 4 nodes
# Community 388: 4 nodes
# Community 400: 4 nodes
# Community 405: 4 nodes
# Community 423: 4 nodes
# Community 432: 4 nodes
# Community 438: 4 nodes
# Community 441: 4 nodes
# Community 442: 4 nodes
# Community 448: 4 nodes
# Community 450: 4 nodes
# Community 453: 4 nodes
# Community 459: 4 nodes
# Community 477: 4 nodes
# Community 478: 4 nodes
# Community 483: 4 nodes
# Community 489: 4 nodes
# Community 504: 4 nodes
# Community 505: 4 nodes
# Community 513: 4 nodes
# Community 515: 4 nodes
# Community 523: 4 nodes
# Community 538: 4 nodes
# Community 546: 4 nodes
# Community 547: 4 nodes
# Community 549: 4 nodes
# Community 550: 4 nodes
# Community 557: 4 nodes
# Community 561: 4 nodes
# Community 563: 4 nodes
# Community 565: 4 nodes
# Community 568: 4 nodes
# Community 573: 4 nodes
# Community 579: 4 nodes
# Community 583: 4 nodes
# Community 588: 4 nodes
# Community 590: 4 nodes
# Community 598: 4 nodes
# Community 601: 4 nodes
# Community 603: 4 nodes
# Community 604: 4 nodes
# Community 606: 4 nodes
# Community 609: 4 nodes
# Community 612: 4 nodes
# Community 613: 4 nodes
# Community 617: 4 nodes
# Community 623: 4 nodes
# Community 625: 4 nodes
# Community 636: 4 nodes
# Community 643: 4 nodes
# Community 646: 4 nodes
# Community 647: 4 nodes
# Community 649: 4 nodes
# Community 662: 4 nodes
# Community 671: 4 nodes
# Community 673: 4 nodes
# Community 677: 4 nodes
# Community 681: 4 nodes
# Community 684: 4 nodes
# Community 687: 4 nodes
# Community 689: 4 nodes
# Community 692: 4 nodes
# Community 694: 4 nodes
# Community 696: 4 nodes
# Community 700: 4 nodes
# Community 702: 4 nodes
# Community 706: 4 nodes
# Community 712: 4 nodes
# Community 718: 4 nodes
# Community 722: 4 nodes
# Community 730: 4 nodes
# Community 732: 4 nodes
# Community 734: 4 nodes
# Community 737: 4 nodes
# Community 738: 4 nodes
# Community 744: 4 nodes
# Community 747: 4 nodes
# Community 748: 4 nodes
# Community 749: 4 nodes
# Community 754: 4 nodes
# Community 758: 4 nodes
# Community 759: 4 nodes
# Community 766: 4 nodes
# Community 767: 4 nodes
# Community 772: 4 nodes
# Community 773: 4 nodes
# Community 774: 4 nodes
# Community 776: 4 nodes
# Community 777: 4 nodes
# Community 781: 4 nodes
# Community 783: 4 nodes
# Community 18: 4 nodes
# Community 21: 4 nodes
# Community 47: 4 nodes
# Community 67: 4 nodes
# Community 87: 4 nodes
# Community 43: 3 nodes
# Community 44: 3 nodes
# Community 45: 3 nodes
# Community 49: 3 nodes
# Community 52: 3 nodes
# Community 78: 3 nodes
# Community 79: 3 nodes
# Community 99: 3 nodes
# Community 105: 3 nodes
# Community 139: 3 nodes
# Community 140: 3 nodes
# Community 141: 3 nodes
# Community 147: 3 nodes
# Community 155: 3 nodes
# Community 156: 3 nodes
# Community 169: 3 nodes
# Community 178: 3 nodes
# Community 186: 3 nodes
# Community 188: 3 nodes
# Community 189: 3 nodes
# Community 192: 3 nodes
# Community 199: 3 nodes
# Community 204: 3 nodes
# Community 206: 3 nodes
# Community 208: 3 nodes
# Community 216: 3 nodes
# Community 231: 3 nodes
# Community 242: 3 nodes
# Community 247: 3 nodes
# Community 251: 3 nodes
# Community 267: 3 nodes
# Community 269: 3 nodes
# Community 275: 3 nodes
# Community 276: 3 nodes
# Community 280: 3 nodes
# Community 282: 3 nodes
# Community 283: 3 nodes
# Community 285: 3 nodes
# Community 315: 3 nodes
# Community 316: 3 nodes
# Community 318: 3 nodes
# Community 329: 3 nodes
# Community 331: 3 nodes
# Community 340: 3 nodes
# Community 342: 3 nodes
# Community 345: 3 nodes
# Community 346: 3 nodes
# Community 349: 3 nodes
# Community 350: 3 nodes
# Community 352: 3 nodes
# Community 360: 3 nodes
# Community 364: 3 nodes
# Community 369: 3 nodes
# Community 376: 3 nodes
# Community 377: 3 nodes
# Community 378: 3 nodes
# Community 390: 3 nodes
# Community 391: 3 nodes
# Community 397: 3 nodes
# Community 402: 3 nodes
# Community 421: 3 nodes
# Community 427: 3 nodes
# Community 434: 3 nodes
# Community 443: 3 nodes
# Community 445: 3 nodes
# Community 449: 3 nodes
# Community 458: 3 nodes
# Community 461: 3 nodes
# Community 462: 3 nodes
# Community 466: 3 nodes
# Community 467: 3 nodes
# Community 468: 3 nodes
# Community 469: 3 nodes
# Community 471: 3 nodes
# Community 472: 3 nodes
# Community 474: 3 nodes
# Community 484: 3 nodes
# Community 485: 3 nodes
# Community 487: 3 nodes
# Community 492: 3 nodes
# Community 495: 3 nodes
# Community 497: 3 nodes
# Community 506: 3 nodes
# Community 509: 3 nodes
# Community 512: 3 nodes
# Community 526: 3 nodes
# Community 529: 3 nodes
# Community 541: 3 nodes
# Community 543: 3 nodes
# Community 544: 3 nodes
# Community 545: 3 nodes
# Community 548: 3 nodes
# Community 551: 3 nodes
# Community 562: 3 nodes
# Community 567: 3 nodes
# Community 569: 3 nodes
# Community 571: 3 nodes
# Community 575: 3 nodes
# Community 580: 3 nodes
# Community 582: 3 nodes
# Community 586: 3 nodes
# Community 587: 3 nodes
# Community 591: 3 nodes
# Community 593: 3 nodes
# Community 594: 3 nodes
# Community 596: 3 nodes
# Community 597: 3 nodes
# Community 599: 3 nodes
# Community 602: 3 nodes
# Community 605: 3 nodes
# Community 607: 3 nodes
# Community 608: 3 nodes
# Community 610: 3 nodes
# Community 614: 3 nodes
# Community 619: 3 nodes
# Community 624: 3 nodes
# Community 627: 3 nodes
# Community 628: 3 nodes
# Community 630: 3 nodes
# Community 632: 3 nodes
# Community 638: 3 nodes
# Community 639: 3 nodes
# Community 640: 3 nodes
# Community 641: 3 nodes
# Community 644: 3 nodes
# Community 645: 3 nodes
# Community 652: 3 nodes
# Community 653: 3 nodes
# Community 655: 3 nodes
# Community 656: 3 nodes
# Community 658: 3 nodes
# Community 659: 3 nodes
# Community 660: 3 nodes
# Community 663: 3 nodes
# Community 666: 3 nodes
# Community 669: 3 nodes
# Community 672: 3 nodes
# Community 674: 3 nodes
# Community 678: 3 nodes
# Community 682: 3 nodes
# Community 688: 3 nodes
# Community 697: 3 nodes
# Community 701: 3 nodes
# Community 703: 3 nodes
# Community 704: 3 nodes
# Community 705: 3 nodes
# Community 707: 3 nodes
# Community 708: 3 nodes
# Community 709: 3 nodes
# Community 710: 3 nodes
# Community 711: 3 nodes
# Community 717: 3 nodes
# Community 719: 3 nodes
# Community 720: 3 nodes
# Community 724: 3 nodes
# Community 725: 3 nodes
# Community 726: 3 nodes
# Community 727: 3 nodes
# Community 728: 3 nodes
# Community 729: 3 nodes
# Community 731: 3 nodes
# Community 733: 3 nodes
# Community 741: 3 nodes
# Community 742: 3 nodes
# Community 746: 3 nodes
# Community 751: 3 nodes
# Community 753: 3 nodes
# Community 756: 3 nodes
# Community 757: 3 nodes
# Community 763: 3 nodes
# Community 765: 3 nodes
# Community 768: 3 nodes
# Community 770: 3 nodes
# Community 771: 3 nodes
# Community 775: 3 nodes
# Community 778: 3 nodes
# Community 779: 3 nodes
# Community 785: 3 nodes
# Community 786: 3 nodes
# Community 787: 3 nodes
# Community 16: 3 nodes
# Community 152: 3 nodes
# Community 26: 3 nodes
# Community 27: 3 nodes
# Community 33: 3 nodes
# Community 36: 3 nodes
# Community 39: 3 nodes
# Community 42: 3 nodes
# Community 54: 3 nodes
# Community 58: 3 nodes
# Community 68: 3 nodes
# Community 84: 3 nodes
# Community 85: 3 nodes
# Community 94: 3 nodes
# Community 100: 3 nodes
# Community 75: 2 nodes

# %%
def read_directed_graph(file_path, skip_lines):
    G = nx.DiGraph()  # Initialize an empty directed graph
    with open(file_path, 'r') as file:
        for _ in range(skip_lines):
            next(file)  # Skip the initial descriptive lines
        for line in file:
            parts = line.strip().split()
            if len(parts) == 2:  # Only consider lines with exactly two node identifiers
                u, v = parts
                G.add_edge(u, v)
    
    return G


def leader_rank(G2, damping=0.85, tol=1e-6, max_iter=100):
    # Add the ground node connected to all other nodes
    ground_node = 'ground'
    G = G2.copy()
    G.add_node(ground_node)
    for node in set(G.nodes()) - {ground_node}:
        G.add_edge(ground_node, node)

    # Create a mapping from node to index
    node_list = list(G.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}
    n = len(node_list)
    
    # Initialize scores to 1 for all nodes
    scores = np.ones(n)
    
    # Create adjacency matrix
    row = []
    col = []
    data = []
    for node in G.nodes():
        neighbors = list(G.neighbors(node))
        if neighbors:
            for neighbor in neighbors:
                row.append(node_index[neighbor])
                col.append(node_index[node])
                data.append(1.0 / len(neighbors))
    
    adjacency_matrix = csr_matrix((data, (row, col)), shape=(n, n))
    
    # Power iteration: iterate until convergence
    for _ in range(max_iter):
        new_scores = adjacency_matrix.dot(scores)
        new_scores[node_index[ground_node]] = np.sum(scores)  # Special handling for the ground node
        if np.linalg.norm(new_scores - scores, 1) < tol:
            scores = new_scores
            break
        scores = new_scores
    
    # Remove the ground node score and normalize the scores
    ground_node_score = scores[node_index[ground_node]]
    total_score = np.sum(scores) - ground_node_score
    scores = (scores - ground_node_score / n) / total_score
    
    # Create the final scores dictionary
    final_scores = {node_list[i]: scores[i] for i in range(n) if node_list[i] != ground_node}
    
    return final_scores





def calculate_h_index(G):
    h_index = {}
    for node in G.nodes():
        degrees = [G.degree(neighbor) for neighbor in G.neighbors(node)]
        degrees.sort(reverse=True)
        h = 0
        for i, degree in enumerate(degrees):
            if degree >= i + 1:
                h = i + 1
            else:
                break
        h_index[node] = h
    return h_index

# %%
# Initialize an empty directed graph
# Load the .mtx file
wiki_path = '/Users/qing/Desktop/24s1/comp8880/project/code/data/wiki-Vote.txt'
G_wiki = read_directed_graph(wiki_path,4)
# Calculate number of nodes and edges in the graph
num_nodes = G_wiki.number_of_nodes()
num_edges = G_wiki.number_of_edges()

num_nodes, num_edges

centrality = nx.degree_centrality(G_wiki)
betweenness_manual = nx.betweenness_centrality(G_wiki)
closeness_manual = nx.closeness_centrality(G_wiki)
pagerank = nx.pagerank(G_wiki, alpha=0.85, personalization=None)
leaderRank = leader_rank(G_wiki)
hIndex = calculate_h_index(G_wiki)
kShell = nx.core_number(G_wiki)

sorted_centrality = sorted(centrality.items(), key=lambda item: item[1], reverse=True)
sorted_betweenness = sorted(betweenness_manual.items(), key=lambda item: item[1], reverse=True)
sorted_closeness = sorted(closeness_manual.items(), key=lambda item: item[1], reverse=True)
sorted_pagerank =  sorted(pagerank.items(), key=lambda item: item[1], reverse=True)
sorted_leaderRank =  sorted(leaderRank.items(), key=lambda item: item[1], reverse=True)
sorted_hIndex =  sorted(hIndex.items(), key=lambda item: item[1], reverse=True)
sorted_kShell=  sorted(kShell.items(), key=lambda item: item[1], reverse=True)


print(sorted_centrality[:3])
print(sorted_betweenness[:3])
print(sorted_closeness[:3])
print(sorted_pagerank[:3])
print(sorted_leaderRank[:3])
print(sorted_hIndex[:3])
print(sorted_kShell[:3])



# 假设 sorted_centrality, sorted_betweenness 等都是已经计算好并排序的元组列表
data_to_save = {
    "Centrality": sorted_centrality,
    "Betweenness": sorted_betweenness,
    "Closeness": sorted_closeness,
    "PageRank": sorted_pagerank,
    "LeaderRank": sorted_leaderRank,
    "HIndex": sorted_hIndex,
    "KShell": sorted_kShell
}

with open('saved/network_metrics_wiki.json', 'w') as f:
    json.dump(data_to_save, f, indent=4)
